# %%
import APEX as ap

# %%
DESI_files = [f"../CIB-Project/apex-outputs/loggedNgg/DESI-full-data-vector-test{i}.txt" for i in range(0, 25)]

# %%
# calculate the error for the galaxy biases

b_g_names = [f"b_g{i}" for i in range(0, 4)]
b_g_err = [ap.MCMCWorkspace.estimate_error(DESI_files, b_g_name) for b_g_name in b_g_names]

print(b_g_err)
# Out:
# /mnt/users/durrantn/APEX/InputHandler.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(chain_outputs[i], delim_whitespace=True)
# /mnt/users/durrantn/APEX/InputHandler.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(chain_outputs[i], delim_whitespace=True)
# /mnt/users/durrantn/APEX/InputHandler.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(chain_outputs[i], delim_whitespace=True)
# /mnt/users/durrantn/APEX/InputHandler.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(chain_outputs[i], delim_whitespace=True)
# ...
